# %% [markdown]
# ### Machine Learning Preprocessing

# %%
# get libraries
import pandas as pd

# %% [markdown]
# 1. Read the data and store it in dataframe

# %%
# YOUR CODE HERE
# df =

# %% [markdown]
# 2. Look at the data
#
#     a. Print first few lines
#
#     b. info about dataset
#
#     c. datatypes of each column

# %%
# YOUR CODE HERE

# %% [markdown]
# Getting data points with Pandas

# %%
# input rows
# select rows 0 to 4 using loc 
# YOUR CODE HERE

# %%
# input row numbers, column names
# select rows 0 to 4 using loc but filter to just view company and price for these 4 rows

# %%
 # use 'select' variable to filter prices greater than 1000
# YOUR CODE HERE
# use loc and filter by the select variable
# YOUR CODE HERE

# %% [markdown]
# Duplicated values
#
# Data points that are exactly the same

# %%
# get boolean array of duplicated rows
# YOUR CODE HERE

# %%
# return a new df without duplicates
# YOUR CODE HERE

# %% [markdown]
# Null Values
# Features of data points we’re missing (also called NaN)
# We want to remove or fill these data points

# %%
#  return a boolean for each value
# YOUR CODE HERE

# %%
df.isna().any(axis=1)  # returns a boolean for each row if any feature is null
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.isna().any(axis=1)  # returns a boolean for each row if any feature is null
#
# NameError: name 'df' is not defined

# %%
 #  return a new df without rows that have null
# YOUR CODE HERE
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1267      1298.0  Lenovo  2 in 1 Convertible     14
# 1268      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1269      1300.0  Lenovo            Notebook     14
# 1270      1301.0      HP            Notebook   15.6
# 1271      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
# first we have to remove the " kg" string from the values

 # remove the " kg" string
# df["Weight (kg)"] = # YOUR CODE HERE

print(df["Weight (kg)"])
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1297     1.8
# 1298     1.3
# 1299     1.5
# 1300    2.19
# 1301     2.2
# Name: Weight (kg), Length: 1302, dtype: object

# %%
# now we can convert to float
df["Weight (kg)"] = df["Weight (kg)"].astype("float")

# %%
# another method - convert to numeric, setting errors to coerce will turn invalid parsing into NaN
# pd.to_numeric(s.str.replace("kg", "", regex=False).str.strip(), errors="coerce")

# %%
# change dtype of columns that should be numeric using astype
df["Price"] =  # YOUR CODE HERE

# %%
df.dtypes
# should see weight in kg is a float now
# Out:
# Unnamed: 0          float64
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight (kg)         float64
# Weight (lbs)         object
# Price               float64
# dtype: object

# %% [markdown]
# Repeated measurements and extra columns
# Remove repeat columns, dates/IDs
# These can skew model towards arbitrary features
# Which columns should we remove in this sample?

# %%
df = df.drop(["Unnamed: 0", "Weight (lbs)"], axis=1)

# %%
# change dtype of columns that should be numeric using astype
# df["Weight"] = df["Weight"].astype("float")this will cause an error right now
print(df["Weight (kg)"])
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1297    1.80
# 1298    1.30
# 1299    1.50
# 1300    2.19
# 1301    2.20
# Name: Weight (kg), Length: 1302, dtype: float64

# %%
df.sort_values(by="Price", ascending=False)
# Out:
#      Company     TypeName Inches                     ScreenResolution  \
# 196    Razer       Gaming   17.3  4K Ultra HD / Touchscreen 3840x2160
# 829    Razer       Gaming   17.3  4K Ultra HD / Touchscreen 3840x2160
# 609   Lenovo     Notebook   15.6      IPS Panel 4K Ultra HD 3840x2160
# 748       HP  Workstation   17.3          IPS Panel Full HD 1920x1080
# 1065    Asus       Gaming   17.3          IPS Panel Full HD 1920x1080
# ...      ...          ...    ...                                  ...
# 977      NaN          NaN    NaN                                  NaN
# 993      NaN          NaN    NaN                                  NaN
# 1059     NaN          NaN    NaN                                  NaN
# 1201     NaN          NaN    NaN                                  NaN
# 1244     NaN          NaN    NaN                                  NaN
#
#                                 Cpu   Ram     Memory                      Gpu  \
# ...

# %%
# use df.to_csv('') to save to new csv
# YOUR CODE HERE
